# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
from random import choice
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_distances, euclidean_distances
from sklearn.decomposition import LatentDirichletAllocation

# %%
def decode_lyrics(s):
    s = s.encode('ascii', 'ignore')
    s = s.decode()
    s = s.replace('\n', ' ')
    s = s.replace('-', ' ')
    s = re.sub(r'[\[].*?[\)\]]', ' ', s)
    
    return s

# %%
# !pwd
# Out:
# /home/ubuntu/vinyl-record-recommender/src/server_src

# %%
dfs = pickle.load(open('dfs_w_lyrics.pkl', 'rb'))
tracks = pd.concat(dfs)
tracks.reset_index(inplace=True)
lead_artist = []
feat_artists = []

for artists in tracks.artist:
    lead_artist.append(artists[0])
    feat_artists.append(artists[1:])

tracks['lead_artist'] = lead_artist
tracks['feat_artists'] = feat_artists
tracks['album_release'] = tracks.album + ' by ' + tracks.lead_artist

# %%
lyrics_flag = pd.isna(tracks['lyrics'])
lyrical_db = tracks[~lyrics_flag]
lyrical_db = lyrical_db[['album_release', 'lyrics']]

# %%
lyrics_by_album = lyrical_db.groupby('album_release')['lyrics'].apply(lambda x: ' '.join(x))

# %%
lyrics_by_album = lyrics_by_album.apply(decode_lyrics)

# %%
lyrics_by_album = lyrics_by_album.apply(decode_lyrics)

# %%
mapping = pd.Series(lyrics_by_album.reset_index().index, index=lyrics_by_album.reset_index().album_release)
mapping
# Out:
# album_release
# - Ugh, those feels again by Snoh Aalegra                0
# 17 by XXXTENTACION                                      1
# A Fever You Can't Sweat Out by Panic! At The Disco      2
# A Letter To My Younger Self by Quinn XCII               3
# A Love Letter To You 3 by Trippie Redd                  4
#                                                      ...
# you broke me first by Tate McRae                      489
# you ruined new york city for me by FLETCHER           490
# zero_one by The Living Tombstone                      491
# ~how i'm feeling~ by Lauv                             492
# ÷ (Deluxe) by Ed Sheeran                              493
# Length: 494, dtype: int64

# %%
album_df = lyrics_by_album.reset_index()
album_df
# Out:
#                                          album_release  \
# 0             - Ugh, those feels again by Snoh Aalegra
# 1                                   17 by XXXTENTACION
# 2    A Fever You Can't Sweat Out by Panic! At The D...
# 3            A Letter To My Younger Self by Quinn XCII
# 4               A Love Letter To You 3 by Trippie Redd
# ..                                                 ...
# 489                   you broke me first by Tate McRae
# 490        you ruined new york city for me by FLETCHER
# 491                   zero_one by The Living Tombstone
# 492                          ~how i'm feeling~ by Lauv
# 493                           ÷ (Deluxe) by Ed Sheeran
#
#                                                 lyrics
# 0    Even if we catch the sunrise It's only a momen...
# 1      17. A collection of nightmares, thoughts, an...
# 2      (Niemieckich spotkao si z szerokim rozgosem ...
# 3      I think the back door creaks I think the sun...
# 4      DJ on the beat so it's a banger (It ain't ov...
# ..                                                 ...
# 489    You broke me first    Maybe you don't like t...
# 490    I poured you a glass of wine And drank it fo...
# 491    Quarter to two and I haven't got out of bed ...
# 492    Another life, another story She walked out, ...
# 493    I was born inside a small town, I lost that ...
#
# [494 rows x 2 columns]

# %% [markdown]
# ### BASELINE MODEL

# %% [markdown]
# ### Manually test albums

# %% [markdown]
# ### HYPERPARAMETERS

# %%
max_features = 1000

# %%
vc = CountVectorizer(max_features=max_features)

# %%
album_df.set_index('album_release', inplace=True)

# %%
lyrics = album_df.lyrics

# %%
M = vc.fit_transform(lyrics)

# %%
words = vc.get_feature_names()

# %%
lda = LatentDirichletAllocation(n_components=30,
                               n_jobs=-1)

# %%
lda.fit(M)
# Out:
# LatentDirichletAllocation(n_components=30, n_jobs=-1)

# %%
theta = lda.transform(M)
phi = lda.components_

theta, phi = (np.around(x,2) for x in (theta, phi))
theta = pd.DataFrame(theta, index=lyrics.index)
phi = pd.DataFrame(phi, columns=words)

print('Theta:')
display(theta)
print('Phi:')
display(phi)
# Out:
# Theta:
#                                                       0     1    2     3   \
# album_release
# - Ugh, those feels again by Snoh Aalegra            0.00  0.00  0.0  0.00
# 17 by XXXTENTACION                                  0.00  0.00  0.0  0.00
# A Fever You Can't Sweat Out by Panic! At The Disco  0.00  0.41  0.0  0.00
# A Letter To My Younger Self by Quinn XCII           0.00  0.40  0.0  0.00
# A Love Letter To You 3 by Trippie Redd              0.06  0.08  0.0  0.00
# ...                                                  ...   ...  ...   ...
# you broke me first by Tate McRae                    0.00  0.00  0.0  0.00
# you ruined new york city for me by FLETCHER         0.00  0.41  0.0  0.00
# zero_one by The Living Tombstone                    0.00  0.34  0.0  0.00
# ~how i'm feeling~ by Lauv                           0.00  0.28  0.0  0.01
# ÷ (Deluxe) by Ed Sheeran                            0.00  0.71  0.0  0.00
#
#                                                      4     5     6     7   \
# album_release
# - Ugh, those feels again by Snoh Aalegra            0.0  0.00  0.09  0.00
# 17 by XXXTENTACION                                  0.0  0.00  0.00  0.00
# A Fever You Can't Sweat Out by Panic! At The Disco  0.0  0.00  0.00  0.16
# A Letter To My Younger Self by Quinn XCII           0.0  0.00  0.07  0.03
# A Love Letter To You 3 by Trippie Redd              0.0  0.00  0.00  0.00
# ...                                                 ...   ...   ...   ...
# you broke me first by Tate McRae                    0.0  0.00  0.00  0.00
# you ruined new york city for me by FLETCHER         0.0  0.05  0.00  0.00
# zero_one by The Living Tombstone                    0.0  0.00  0.00  0.12
# ~how i'm feeling~ by Lauv                           0.0  0.00  0.06  0.00
# ÷ (Deluxe) by Ed Sheeran                            0.0  0.00  0.01  0.06
#
#                                                       8    9   ...    20  \
# album_release                                                  ...
# - Ugh, those feels again by Snoh Aalegra            0.00  0.0  ...  0.00
# 17 by XXXTENTACION                                  0.00  0.0  ...  0.00
# A Fever You Can't Sweat Out by Panic! At The Disco  0.00  0.0  ...  0.00
# A Letter To My Younger Self by Quinn XCII           0.00  0.0  ...  0.00
# A Love Letter To You 3 by Trippie Redd              0.00  0.0  ...  0.00
# ...                                                  ...  ...  ...   ...
# you broke me first by Tate McRae                    0.00  0.0  ...  0.00
# you ruined new york city for me by FLETCHER         0.00  0.0  ...  0.00
# zero_one by The Living Tombstone                    0.00  0.0  ...  0.00
# ~how i'm feeling~ by Lauv                           0.02  0.0  ...  0.05
# ÷ (Deluxe) by Ed Sheeran                            0.00  0.0  ...  0.00
#
#                                                       21    22    23   24  \
# album_release
# - Ugh, those feels again by Snoh Aalegra            0.00  0.00  0.00  0.0
# 17 by XXXTENTACION                                  0.00  0.96  0.00  0.0
# A Fever You Can't Sweat Out by Panic! At The Disco  0.00  0.00  0.00  0.0
# A Letter To My Younger Self by Quinn XCII           0.00  0.00  0.02  0.0
# A Love Letter To You 3 by Trippie Redd              0.14  0.00  0.00  0.0
# ...                                                  ...   ...   ...  ...
# you broke me first by Tate McRae                    0.00  0.00  0.00  0.0
# you ruined new york city for me by FLETCHER         0.00  0.00  0.00  0.0
# zero_one by The Living Tombstone                    0.00  0.00  0.00  0.0
# ~how i'm feeling~ by Lauv                           0.00  0.06  0.00  0.0
# ÷ (Deluxe) by Ed Sheeran                            0.00  0.01  0.00  0.0
#
#                                                      25    26   27   28    29
# album_release
# - Ugh, those feels again by Snoh Aalegra            0
# Index(['- Ugh, those feels again by Snoh Aalegra', '17 by XXXTENTACION',
#        'A Fever You Can't Sweat Out by Panic! At The Disco',
#        'A Letter To My Younger Self by Quinn XCII',
#        'A Love Letter To You 3 by Trippie Redd',
#        'A Love Letter To You 4 by Trippie Redd',
#        'A Love Letter To You by Trippie Redd',
#        'AI YoungBoy 2 by YoungBoy Never Broke Again', 'AM by Arctic Monkeys',
#        'ANTI (Deluxe) by Rihanna',
#        ...
#        'thank u, next by Ariana Grande', 'us by gnash',
#        'x (Deluxe Edition) by Ed Sheeran', 'xx by The xx', 'ye by Kanye West',
#        'you broke me first by Tate McRae',
#        'you ruined new york city for me by FLETCHER',
#        'zero_one by The Living Tombstone', '~how i'm feeling~ by Lauv',
#        '÷ (Deluxe) by Ed Sheeran'],
#       dtype='object', name='album_release', length=494)

# %%
album_features = pd.concat([album_avg_feature, theta], axis=1)

# %%
album_features
# Out:
#                                                     danceability    energy  \
# album_release
# - Ugh, those feels again by Snoh Aalegra                0.588143  0.490429
# 17 by XXXTENTACION                                      0.689273  0.250527
# A Fever You Can't Sweat Out by Panic! At The Disco      0.500462  0.790615
# A Letter To My Younger Self by Quinn XCII               0.712750  0.550750
# A Love Letter To You 3 by Trippie Redd                  0.676250  0.585125
# ...                                                          ...       ...
# you broke me first by Tate McRae                        0.642000  0.374000
# you ruined new york city for me by FLETCHER             0.567800  0.627000
# zero_one by The Living Tombstone                        0.525300  0.899800
# ~how i'm feeling~ by Lauv                               0.670667  0.451952
# ÷ (Deluxe) by Ed Sheeran                                0.661062  0.578500
#
#                                                          key   loudness  \
# album_release
# - Ugh, those feels again by Snoh Aalegra            6.500000  -9.584857
# 17 by XXXTENTACION                                  4.636364 -15.489545
# A Fever You Can't Sweat Out by Panic! At The Disco  7.076923  -5.923923
# A Letter To My Younger Self by Quinn XCII           4.416667  -6.694333
# A Love Letter To You 3 by Trippie Redd              5.562500  -7.203437
# ...                                                      ...        ...
# you broke me first by Tate McRae                    4.000000  -9.386000
# you ruined new york city for me by FLETCHER         6.400000  -5.829800
# zero_one by The Living Tombstone                    5.500000  -4.177600
# ~how i'm feeling~ by Lauv                           6.571429  -8.344190
# ÷ (Deluxe) by Ed Sheeran                            5.437500  -5.622937
#
#                                                         mode  speechiness  \
# album_release
# - Ugh, those feels again by Snoh Aalegra            0.357143     0.138764
# 17 by XXXTENTACION                                  0.272727     0.216018
# A Fever You Can't Sweat Out by Panic! At The Disco  0.307692     0.138192
# A Letter To My Younger Self by Quinn XCII           0.583333     0.076492
# A Love Letter To You 3 by Trippie Redd              0.500000     0.101037
# ...                                                      ...          ...
# you broke me first by Tate McRae                    1.000000     0.054500
# you ruined new york city for me by FLETCHER         1.000000     0.137620
# zero_one by The Living Tombstone                    0.700000     0.077480
# ~how i'm feeling~ by Lauv                           0.857143     0.105490
# ÷ (Deluxe) by Ed Sheeran                            0.812500     0.067769
#
#                                                     acousticness  \
# album_release
# - Ugh, those feels again by Snoh Aalegra                0.435457
# 17 by XXXTENTACION                                      0.618655
# A Fever You Can't Sweat Out by Panic! At The Disco      0.188285
# A Letter To My Younger Self by Quinn XCII               0.309169
# A Love Letter To You 3 by Trippie Redd                  0.139309
# A Fever You Can't Sweat Out by Panic! At The Disco  0.00  0.11
# A Letter To My Younger Self by Quinn XCII           0.00  0.33
# A Love Letter To You 3 by Trippie Redd              0.00  0.00
# ...                                                  ...   ...
# you broke me first by Tate McRae                    0.00  0.69
# you ruined new york city for me by FLETCHER         0.00  0.73
# zero_one by The Living Tombstone                    0.00  0.28
# ~how i'm feeling~ by Lauv                           0.00  0.13
# ÷ (Deluxe) by Ed Sheeran                            0.00  0.24
#
# [494 rows x 43 columns]

# %% [markdown]
# # Recommender Functions

# %%
tfidf = TfidfVectorizer(stop_words='english')
lyric_vec = tfidf.fit_transform(lyrics_by_album)
print(f'{tracks.album.nunique()} albums.')
print(f'{lyric_vec.shape[1]} unique single n-grams in album corpus.')
# Out:
# 508 albums.
# 59938 unique single n-grams in album corpus.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_test = album_features.values

# %%
X_scaled = scaler.fit_transform(X_test)

# %%
X = album_features.values
lyric_vec = tfidf.fit_transform(lyrics_by_album)

# %%
def recommended_albums_lyrics(sample_album, lyric_vec):
    similarity_matrix = cosine_similarity(lyric_vec, lyric_vec)
    
    album_index = mapping[sample_album]
    similarity_score = list(enumerate(similarity_matrix[album_index]))
    similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)
    
    # get score of 10 most similar movies. Ignore first movie.
    similarity_score = similarity_score[1:10]
    
    # return movie names using the mapping series
    
    album_indices = [i[0] for i in similarity_score]
    
    return (album_df['album_release'].iloc[album_indices])

# %%
def recommended_albums_topics(sample_album, X):
    similarity_matrix = cosine_similarity(X, X)
    
    album_index = mapping[sample_album]
    similarity_score = list(enumerate(similarity_matrix[album_index]))
    similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)
    
    # get score of 10 most similar movies. Ignore first movie.
    similarity_score = similarity_score[1:6]
    
    # return movie names using the mapping series
    
    album_indices = [i[0] for i in similarity_score]
    
    return (album_df['album_release'].iloc[album_indices])

# %%
album_df.reset_index(inplace=True)

# %%
album_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-16af9813090c> in <module>
# ----> 1 album_df
#
# NameError: name 'album_df' is not defined

# %%
for album in lyrical_db.album_release.unique():
    print(album)
# Out:
# After Hours by The Weeknd
# ASTROWORLD by Travis Scott
# American Teen by Khalid
# AI YoungBoy 2 by YoungBoy Never Broke Again
# A Love Letter To You 4 by Trippie Redd
# Artist 2.0 by A Boogie Wit da Hoodie
# ANTI (Deluxe) by Rihanna
# A Love Letter To You 3 by Trippie Redd
# A Letter To My Younger Self by Quinn XCII
# AM by Arctic Monkeys
# Appetite For Destruction by Guns N' Roses
# Artist 2.0 (Deluxe) by A Boogie Wit da Hoodie
# AT.LONG.LAST.A$AP by A$AP Rocky
# A Fever You Can't Sweat Out by Panic! At The Disco
# American Beauty/American Psycho by Fall Out Boy
# A Love Letter To You by Trippie Redd
# Artist by A Boogie Wit da Hoodie
# beerbongs & bentleys by Post Malone
# Blonde by Frank Ocean
# BALLADS 1 by Joji
# B4 The Storm by Internet Money
# Birds In The Trap Sing McKnight by Travis Scott
# Birds In The Trap Sing McKnight by Young Thug
# Beauty Behind The Madness by The Weeknd
# Blurryface by Twenty One Pilots
# Be Like That (feat. Swae Lee & Khalid) by Kane Brown
# Baby On Baby by DaBaby
# Blueberry Faygo by Lil Mosey
# Breaking Me by Topic
# Back from the Edge by James Arthur
# Traveller by Chris Stapleton
# T R A P S O U L by Bryson Tiller
# There's Really A Wolf by Russ
# THE SCOTTS by THE SCOTTS
# The New Toronto 3 by Tory Lanez
# The Black Parade by My Chemical Romance
# Take Me Home (Expanded Edition) by One Direction
# Ugly is Beautiful by Oliver Tree
# UN DIA (ONE DAY) (Feat. Tainy) by J Balvin
# Up All Night by One Direction
# Unorthodox Jukebox by Bruno Mars
# Until Death Call My Name (Reloaded) by YoungBoy Never Broke Again
# Ungodly Hour by Chloe x Halle
# UNDERTALE Soundtrack by Toby Fox
# Under Pressure (Deluxe) by Logic
# Ultraviolence (Deluxe) by Lana Del Rey
# - Ugh, those feels again by Snoh Aalegra
# Utopia by Romeo Santos
# Utopia by Anthony Santos
# Utopia by Aventura
# United by Marvin Gaye
# Unleashed by Toby Keith
# Unleashed by Skillet
# Unapologetically (Deluxe Edition) by Kelsea Ballerini
# us by gnash
# Views by Drake
# Vibras de Noche by Eslabon Armado
# V by Maroon 5
# Victory Lap by Nipsey Hussle
# Vroom Vroom by A Boogie Wit da Hoodie
# Vessel by Twenty One Pilots
# Voicenotes by Charlie Puth
# VHS by X Ambassadors
# Viva el Perreo by Jowell & Randy
# Viva La Vida or Death and All His Friends by Coldplay
# Voices by Daryl Hall & John Oates
# Vampire Weekend by Vampire Weekend
# Vices & Virtues by Panic! At The Disco
# VIDA by Luis Fonsi
# Ventura by Anderson .Paak
# Visions by Grimes
# Vibras by J Balvin
# WAP (feat. Megan Thee Stallion) by Cardi B
# WHEN WE ALL FALL ASLEEP, WHERE DO WE GO? by Billie Eilish
# What You See Is What You Get by Luke Combs
# WUNNA by Gunna
# WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) [Remix] by Jack Harlow
# We Love You Tecca by Lil Tecca
# WUNNA (Deluxe) by Gunna
# Where the Light Is by Surfaces
# World War Joy by The Chainsmokers
# Wasteland, Baby! by Hozier
# Without Warning by 21 Savage
# Without Warning by Offset
# What Could Possibly Go Wrong by Dominic Fike
# Walk Em Down (feat. Roddy Ricch) by NLE Choppa
# Wiped Out! by The Neighbourhood
# War & Leisure by Miguel
# Weezer by Weezer
# While We Wait by Kehlani
# We Sing. We Dance. We Steal Things. by Jason Mraz
# X 100PRE by Bad Bunny
# x (Deluxe Edition) by Ed Sheeran
# XXXTENTACION Presents: Members Only, Vol. 3 by XXXTENTACION
# XXXTENTACION Presents: Members Only, Vol. 3 by Craig Xen
# XXXTENTACION Presents: Members Only, Vol. 3 by Cooliecut
# XXXTENTACION Presents: Members Only, Vol. 3 by Kid Trunks
# XXXTENTACION Presents: Members Only, Vol. 3 by Kin$oul
# XXXTENTACION Presents: Members Only, Vol. 3 by Bass Santana
# XXXTENTACION Presents: Members Only, Vol. 3 by Flyboy Tarantino
# X (Expanded Edition) by Chris Brown
# X&Y by Coldplay
# 17 by XXXTENTACION
# XV by Jonas Brothers
# XXXTENTACION Presents: Members Only, Vol. 4 by Corey
# XXXTENTACION Presents: Members Only, Vol. 4 by Cooliecut
# XXXTENTACION Presents: Members Only, Vol. 4 by XXXTENTACION
# XXXTENTACION Presents: Members Only, Vol. 4 by Kid Trunks
# XXXTENTACION Presents: Members Only, Vol. 4 by Tankhead
# XXXTENTACION Presents: Members Only, Vol. 4 by Bass Santana
# XXXTENTACION Presents: Members Only, Vol. 4 by Flyboy Tarantino
# XXXTENTACION Presents: Members Only, Vol. 4 by Killstation
# XXXTENTACION Presents: Members Only, Vol. 4 by Ski Mask The Slump God
# XXXTENTACION Presents: Members Only, Vol. 4 by Craig Xen
# XXXTENTACION Presents: Members Only, Vol. 4 by Ratchet Roach
# xx by The xx
# X by THE DRIVER ERA
# XSCAPE by Michael Jackson
# XO by John Mayer
# Bad Vibes Forever by XXXTENTACION
# Xxotic by Why Cue
# X (feat. Maluma & Ozuna) [Remix] by Nicky Jam
# SKINS by XXXTENTACION
# YHLQMDLG by Bad Bunny
# you broke me first by Tate McRae
# Youngblood (Deluxe) by 5 Seconds of Summer
# Yours by Russell Dickerson
# ye by Kanye West
# You Get What You Give (Deluxe) by Zac Brown Band
# YOU by Ali Gatie
# You Will Regret (Reloaded) by Ski Mask The Slump God
# Yeezus by Kanye West
# you ruined new york city for me by FLETCHER
# Yours Truly by Ariana Grande
# Yours Truly by MIKA
# You Never Walk Alone by BTS
# Young The Giant (Special Edition) by Young the Giant
# Ya Después De Muerto by Chalino Sanchez
# Young & Turnt 2 by 42 Dugg
# Yellow Tape by Key Glock
# You're Somebody Else by flora cash
# ZOO by Russ
# ZOMBIES 2 (Original TV Movie Soundtrack) by Milo Manheim
# ZOMBIES 2 (Original TV Movie Soundtrack) by Chandler Kinney
# ZOMBIES 2 (Original TV Movie Soundtrack) by Meg Donnelly
# ZOMBIES 2 (Original TV Movie Soundtrack) by Baby Ariel
# ZABA by Glass Animals
# ZUU by Denzel Curry
# ZERO : FEVER Part.1 by ATEEZ
# Zion (Deluxe Edition) by Hillsong UNITED
# Z by SZA
# Zelda & Chill by Mikel
# ZOMBIES (Original TV Movie Soundtrack) by Cast - ZOMBIES
# ZOMBIES (Original TV Movie Soundtrack) by Milo Manheim
# ZOMBIES (Original TV Movie Soundtrack) by Meg Donnelly
# Zeros by Declan McKenna
# ZZZ's by B.o.B
# Zombie by Bad Wolves
# Zenyatta Mondatta (Remastered 2003) by The Police
# Zootopia (Original Motion Picture Soundtrack) by Shakira
# Zootopia (Original Motion Picture Soundtrack) by Michael Giacchino
# Zendaya by Zendaya
# The Foundation by Zac Brown Band
# Zephyr by NIKI
# zero_one by The Living Tombstone

# %%
recommended_albums_lyrics('Hotel Diablo by Machine Gun Kelly', lyric_vec)
# Out:
# 343                    There's Really A Wolf by Russ
# 137             Hoodie SZN by A Boogie Wit da Hoodie
# 16     Artist 2.0 (Deluxe) by A Boogie Wit da Hoodie
# 19                    B4 The Storm by Internet Money
# 268                                 Perception by NF
# 17              Artist 2.0 by A Boogie Wit da Hoodie
# 342                                 The Search by NF
# 42                             Circles by Mac Miller
# 106                        Ghetto Gospel by Rod Wave
# Name: album_release, dtype: object

# %%
recs = recommended_albums_topics('Hot Pink by Doja Cat', X_scaled)

# %%
for r in recs:
    print(r)
# Out:
# Breaking Me by Topic
# Romance by Shawn Mendes
# Love Yourself 結 'Answer' by BTS
# Changes by Justin Bieber
# You Never Walk Alone by BTS
