# %%
import pickle

# %%
# !ls -l server_files/src/server_src/
# Out:
# total 305000
# -rw-r--r--@ 1 zschulzb  staff     259926 Nov 17 16:38 LDA and lyric EDA.ipynb
# -rw-r--r--@ 1 zschulzb  staff    5000868 Sep 24 15:20 MASTER_ALBUM_IDS.pkl
# -rw-r--r--@ 1 zschulzb  staff      62813 Sep 24 15:20 album_key_dictionary.pkl
# -rw-r--r--@ 1 zschulzb  staff       6231 Sep 24 15:20 album_scraper.py
# -rw-r--r--@ 1 zschulzb  staff      66148 Sep 24 15:20 albums_w_no_genres.pkl
# -rw-r--r--@ 1 zschulzb  staff        131 Sep 24 15:20 api_keys.txt
# -rw-r--r--@ 1 zschulzb  staff  130541985 Sep 24 15:20 df_for_recommender.pkl
# -rw-r--r--@ 1 zschulzb  staff   18741958 Sep 24 15:20 dfs_w_lyrics.pkl
# -rw-r--r--@ 1 zschulzb  staff      84425 Sep 24 15:20 final_albums_df.pkl
# -rw-r--r--@ 1 zschulzb  staff      88068 Sep 24 15:20 genres_df.pkl
# drwxr-xr-x@ 2 zschulzb  staff         64 Sep 24 15:20 logs
# -rw-r--r--@ 1 zschulzb  staff      15868 Sep 24 15:20 my_personal_albums.ipynb
# -rw-r--r--@ 1 zschulzb  staff     111520 Sep 24 15:20 nlp_eda.ipynb
# ...

# %%
# !ls -l server_files/data
# Out:
# total 46544
# -rw-r--r--@ 1 zschulzb  staff   5000868 Sep 24 15:20 MASTER_ALBUM_IDS.pkl
# -rw-r--r--@ 1 zschulzb  staff  18741958 Sep 24 15:20 dfs_w_lyrics.pkl
# -rw-r--r--@ 1 zschulzb  staff     84425 Sep 24 15:20 final_albums_df.pkl

# %%
with open('server_files/src/server_src/df_for_recommender.pkl', 'rb') as pickle_file:
    data = pickle.load(pickle_file)

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                         danceability    energy       key   loudness      mode  \
# album_id
# 1awdBA8DLv6G5eBvdGxk8T      0.462455  0.873273  5.000000  -4.239455  0.818182
# 0XHpO9qTpqJJQwa2zFxAAE      0.566727  0.619909  5.454545 -10.143727  0.272727
# 5bcobCRR5ovNoZWAp3iJgG      0.643357  0.482071  3.571429 -10.355214  0.571429
# 6Zho4ar8UMxJLMDpWcLGto      0.496250  0.183000  3.250000 -15.064500  1.000000
# 07OjWJVHVzsbZ5ytXhj7ou      0.708667  0.620056  4.000000  -8.682722  0.611111
# ...                              ...       ...       ...        ...       ...
# 2fYhqwDWXjbpjaIJPEfKFw      0.668250  0.525583  4.666667  -6.622000  0.666667
# 0g1F5eGVwX4Sxi1n8ojPkE      0.588000  0.664818  3.818182  -5.072455  0.909091
# 4gvQO5mEuhbMSrLIuwXkmz      0.783400  0.674300  5.900000  -7.241900  0.600000
# 6x4UQQ7TVOja89iXV047Zo      0.348000  0.652000  3.000000  -7.145000  1.000000
# 2xwFfH8fO1MRmWZbNKZVqt      0.502545  0.691636  7.909091  -5.109182  1.000000
#
# ...
